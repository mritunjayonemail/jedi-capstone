# %%
from __future__ import print_function
#import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.colors as colors
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
from sklearn import cross_validation
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import xgboost
from sklearn.metrics import accuracy_score, classification_report, auc, roc_curve, roc_auc_score, confusion_matrix

# %%
ball_by_ball = pd.read_csv("../shared/ipl/data/ball_by_ball.csv")
ball_by_ball.head()
# Out:
#    MatcH_id  Over_id  Ball_id  Innings_No Team_Batting Team_Bowling  \
# 0    598028       15        6           1            5            2
# 1    598028       14        1           1            5            2
# 2    598028       14        2           1            5            2
# 3    598028       14        3           1            5            2
# 4    598028       14        4           1            5            2
#
#    Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 0                       6.0  No Extras            4           0  ...
# 1                       5.0  No Extras            1           0  ...
# 2                       3.0  No Extras            1           0  ...
# 3                       5.0  No Extras            1           0  ...
# 4                       3.0  No Extras            0           0  ...
#
#    Fielder_match_SK  Fielder_SK  Bowler_match_SK  BOWLER_SK  \
# 0                -1          -1            20343         82
# 1                -1          -1            20348        345
# 2                -1          -1            20348        345
# 3                -1          -1            20348        345
# 4                -1          -1            20348        345
#
#    PlayerOut_match_SK  BattingTeam_SK BowlingTeam_SK  Keeper_Catch  \
# 0                  -1               4              1             0
# 1                  -1               4              1             0
# 2                  -1               4              1             0
# 3                  -1               4              1             0
# 4                  -1               4              1             0
#
#    Player_out_sk  MatchDateSK
# 0              0     20130420
# 1              0     20130420
# 2              0     20130420
# 3              0     20130420
# 4              0     20130420
#
# [5 rows x 48 columns]

# %%
matches = pd.read_csv("../shared/ipl/data/matches.csv")
matches.head()
# Out:
#    Match_SK  match_id                        Team1  \
# 0         0    335987  Royal Challengers Bangalore
# 1         1    335988              Kings XI Punjab
# 2         2    335989             Delhi Daredevils
# 3         3    335990               Mumbai Indians
# 4         4    335991        Kolkata Knight Riders
#
#                          Team2 match_date  Season_Year  \
# 0        Kolkata Knight Riders  4/18/2008         2008
# 1          Chennai Super Kings  4/19/2008         2008
# 2             Rajasthan Royals  4/19/2008         2008
# 3  Royal Challengers Bangalore  4/20/2008         2008
# 4              Deccan Chargers  4/20/2008         2008
#
#                                    Venue_Name   City_Name Country_Name  \
# 0                       M Chinnaswamy Stadium   Bangalore        India
# 1  Punjab Cricket Association Stadium, Mohali  Chandigarh        India
# 2                            Feroz Shah Kotla       Delhi        India
# 3                            Wankhede Stadium      Mumbai        India
# 4                                Eden Gardens     Kolkata        India
#
#                    Toss_Winner                 match_winner Toss_Name  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders     field
# 1          Chennai Super Kings          Chennai Super Kings       bat
# 2             Rajasthan Royals             Delhi Daredevils       bat
# 3               Mumbai Indians  Royal Challengers Bangalore       bat
# 4              Deccan Chargers        Kolkata Knight Riders       bat
#
#   Win_Type Outcome_Type    ManOfMach  Win_Margin  Country_id
# 0     runs       Result  BB McCullum       140.0           1
# 1     runs       Result   MEK Hussey        33.0           1
# 2  wickets       Result  MF Maharoof         9.0           1
# 3  wickets       Result   MV Boucher         5.0           1
# 4  wickets       Result    DJ Hussey         5.0           1

# %%
player_list = pd.read_csv("../shared/ipl/data/player_list.csv")
player_list.head()
# Out:
#    PLAYER_SK  Player_Id      Player_Name         DOB    Batting_hand  \
# 0          0          1       SC Ganguly    7/8/1972   Left-hand bat
# 1          1          2      BB McCullum   9/27/1981  Right-hand bat
# 2          2          3       RT Ponting  12/19/1974  Right-hand bat
# 3          3          4        DJ Hussey   7/15/1977  Right-hand bat
# 4          4          5  Mohammad Hafeez  10/17/1980  Right-hand bat
#
#         Bowling_skill Country_Name
# 0    Right-arm medium        India
# 1    Right-arm medium  New Zealand
# 2    Right-arm medium    Australia
# 3  Right-arm offbreak    Australia
# 4  Right-arm offbreak     Pakistan

# %%
player_match_list = pd.read_csv("../shared/ipl/data/player_match_list.csv")
player_match_list.head()
# Out:
#    Player_match_SK  PlayerMatch_key  Match_Id  Player_Id Player_Name  \
# 0               -1    -1.000000e+00        -1         -1         NaN
# 1            12694     3.359870e+10    335987          6    R Dravid
# 2            12695     3.359870e+10    335987          7    W Jaffer
# 3            12696     3.359870e+10    335987          8     V Kohli
# 4            12697     3.359870e+10    335987          9   JH Kallis
#
#           DOB    Batting_hand          Bowling_skill  Country_Name Role_Desc  \
# 0         NaN             NaN                    NaN           NaN       NaN
# 1   1/11/1973  Right-hand bat     Right-arm offbreak         India   Captain
# 2   2/16/1978  Right-hand bat     Right-arm offbreak         India    Player
# 3   11/5/1988  Right-hand bat       Right-arm medium         India    Player
# 4  10/16/1975  Right-hand bat  Right-arm fast-medium  South Africa    Player
#
#    ... Season_year is_manofThematch  Age_As_on_match  IsPlayers_Team_won  \
# 0  ...         NaN              NaN              NaN                 NaN
# 1  ...      2008.0              0.0             35.0                 0.0
# 2  ...      2008.0              0.0             30.0                 0.0
# 3  ...      2008.0              0.0             20.0                 0.0
# 4  ...      2008.0              0.0             33.0                 0.0
#
#    Batting_Status  Bowling_Status  Player_Captain  Opposit_captain  \
# 0             NaN             NaN             NaN              NaN
# 1             NaN             NaN        R Dravid       SC Ganguly
# 2             NaN             NaN        R Dravid       SC Ganguly
# 3             NaN             NaN        R Dravid       SC Ganguly
# 4             NaN             NaN        R Dravid       SC Ganguly
#
#   Player_keeper Opposit_keeper
# 0           NaN            NaN
# 1    MV Boucher        WP Saha
# 2    MV Boucher        WP Saha
# 3    MV Boucher        WP Saha
# 4    MV Boucher        WP Saha
#
# [5 rows x 22 columns]

# %%
teams = pd.read_csv("../shared/ipl/data/teams.csv")
teams.head(10)
# Out:
#    Team_SK  Team_Id                    Team_Name
# 0        0        1        Kolkata Knight Riders
# 1        1        2  Royal Challengers Bangalore
# 2        2        3          Chennai Super Kings
# 3        3        4              Kings XI Punjab
# 4        4        5             Rajasthan Royals
# 5        5        6             Delhi Daredevils
# 6        6        7               Mumbai Indians
# 7        7        8              Deccan Chargers
# 8        8        9         Kochi Tuskers Kerala
# 9        9       10                Pune Warriors

# %% [markdown]
# # a. Venue-wise analysis - The average 1st innings and 2nd innings score across all venues

# %%
innings_score = ball_by_ball[['MatcH_id', 'Innings_No', 'Runs_Scored']]
match_vanue = matches[['match_id', 'Venue_Name']]
venue_inning_score = innings_score.set_index('MatcH_id').join(match_vanue.set_index('match_id'))
venue_inning_score['match_id'] = venue_inning_score.index

# %%
venue_inning_score['Innings_No'].unique()
# Out:
# array([1, 2, 3, 4])

# %%
venue_first_inning_score = venue_inning_score.loc[venue_inning_score.Innings_No == 1].groupby('Venue_Name')[['Runs_Scored']].sum()
venue_second_inning_score = venue_inning_score.loc[venue_inning_score.Innings_No == 2].groupby('Venue_Name')[['Runs_Scored']].sum()

# %%
venue_first_match_count = venue_inning_score[venue_inning_score.Innings_No == 1].groupby('Venue_Name'
                                                                                        )[['match_id']].nunique()

venue_second_match_count = venue_inning_score[venue_inning_score.Innings_No == 2].groupby('Venue_Name'
                                                                                        )[['match_id']].nunique()

# %%
venue_first_inning_score['match_count'] = venue_first_match_count['match_id']
venue_second_inning_score['match_count'] = venue_second_match_count['match_id']

# %%
venue_first_inning_score['average_score'] = venue_first_inning_score['Runs_Scored']*1.0/venue_first_inning_score['match_count']

venue_second_inning_score['average_score'] = venue_second_inning_score['Runs_Scored']*1.0/venue_second_inning_score['match_count']

# %%
venue_average_scores = venue_first_inning_score[['average_score']].join(venue_second_inning_score[['average_score']], lsuffix='_first_innning', rsuffix='_second_inning')

# %%
venue_average_scores
# Out:
#                                                     average_score_first_innning  \
# Venue_Name
# Barabati Stadium                                                     162.285714
# Brabourne Stadium                                                    168.272727
# Buffalo Park                                                         135.333333
# De Beers Diamond Oval                                                152.666667
# Dr DY Patil Sports Academy                                           136.764706
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...                   152.000000
# Dubai International Cricket Stadium                                  138.428571
# Eden Gardens                                                         145.786885
# Feroz Shah Kotla                                                     153.466667
# Green Park                                                           153.250000
# Himachal Pradesh Cricket Association Stadium                         164.888889
# Holkar Cricket Stadium                                               147.200000
# JSCA International Stadium Complex                                   142.857143
# Kingsmead                                                            144.200000
# M Chinnaswamy Stadium                                                158.939394
# MA Chidambaram Stadium, Chepauk                                      157.312500
# Maharashtra Cricket Association Stadium                              157.800000
# Nehru Stadium                                                        138.200000
# New Wanderers Stadium                                                137.250000
# Newlands                                                             132.000000
# OUTsurance Oval                                                      125.500000
# Punjab Cricket Association IS Bindra Stadium Mo...                   151.750000
# Punjab Cricket Association IS Bindra Stadium, M...                   161.428571
# Punjab Cricket Association Stadium, Mohali                           154.485714
# Rajiv Gandhi International Stadium Uppal                             157.250000
# Rajiv Gandhi International Stadium, Uppal                            146.609756
# Sardar Patel Stadium, Motera                                         155.500000
# Saurashtra Cricket Association Stadium                               164.000000
# Sawai Mansingh Stadium                                               145.181818
# Shaheed Veer Narayan Singh International Stadium                     139.500000
# Sharjah Cricket Stadium                                              148.333333
# Sheikh Zayed Stadium                                                 139.285714
# St George's Park                                                     150.571429
# Subrata Roy Sahara Stadium                                           140.235294
# SuperSport Park                                                      144.500000
# Vidarbha Cricket Association Stadium, Jamtha                         139.666667
# Wankhede Stadium                                                     155.175439
#
#                                                     average_score_second_inning
# Venue_Name
# Barabati Stadium                                                     151.285714
# Brabourne Stadium                                                    158.545455
# Buffalo Park                                                         112.000000
# De Beers Diamond Oval                                                133.333333
# Dr DY Patil Sports Academy                                           127.352941
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Sta...                   120.272727
# Dubai International Cricket Stadium                                  139.000000
# Eden Gardens                                                         134.622951
# Feroz Shah Kotla                                                     140.389831
# Green Park                                                           155.750000
# Himachal Pradesh Cricket Association Stadium                         136.888889
# Holkar Cricket Stadium                                               150.200000
# JSCA International Stadium Complex                                   136.571429
# Kingsmead                                                            127.533333
# M Chinnaswamy Stadium                                                137.030769
# MA Chidambaram Stadium, Chepauk                                      143.770833
# Maharashtra Cricket Association Stadium                              144.733333
# Nehru Stadium                                                        119.000000
# New Wanderers Stadium                                                135.750000
# Newlands                                                             104.000000
# OUTsurance Oval                                                      116.500000
# Punjab Cricket Association IS Bindra Stadium Mo...                   144.250000
# Punjab Cricket Association IS Bindra Stadium, M...                   157.428571
# Punjab Cricket Association Stadium, Mohali                           143.257143
# Rajiv Gandhi International Stadium Uppal                             145.125000
# Rajiv Gandhi International Stadium, Uppal                            139.097561
# Sardar Patel Stadium, Motera                                         142.083333
# Saurashtra Cricket Association Stadium                               154.500000
# Sawai Mansingh Stadium                                               134.545455
# Shaheed Veer Narayan Singh International Stadium                     137.833333
# Sharjah Cricket Stadium                                              139.666667
# Sheikh Zayed Stadium                                                 119.571429
# St George's Park                                                     121.428571
# Subrata Roy Sahara Stadium                                           125.529412
# SuperSport Park                                                      142.166667
# Vidarbha Cricket Association Stadium, Jamtha                         134.333333
# Wankhede Stadium                                                     143.000000

# %% [markdown]
# # b. Effect of Toss and home-field advantage on win

# %%
matches['Outcome_Type'].unique()
# Out:
# array(['Result', 'Superover', 'No Result', 'abandoned', 'tied'],
#       dtype=object)

# %%
matches_result = matches.loc[matches.Outcome_Type.isin(['Result', 'Superover'])]

# %%
matches_result.shape
# Out:
# (632, 17)

# %%
matches_toss_winner = matches[matches['Toss_Winner']==matches['match_winner']]
slices=[len(matches_toss_winner),(632-len(matches_toss_winner))]
labels=['yes','no']
plt.pie(slices,labels=labels,startangle=90,shadow=True,explode=(0,0.05),autopct='%1.1f%%',colors=['r','g'])
fig = plt.gcf()
fig.set_size_inches(6,6)
plt.title('Effect of Toss')
plt.show()

# %%
matches_home_team_winner = matches[matches['Team1']==matches['match_winner']]
slices=[len(matches_home_team_winner),(632-len(matches_home_team_winner))]
labels=['yes','no']
plt.pie(slices,labels=labels,startangle=90,shadow=True,explode=(0,0.05),autopct='%1.1f%%',colors=['r','g'])
fig = plt.gcf()
fig.set_size_inches(6,6)
plt.title('Effect of home advantage')
plt.show()

# %% [markdown]
# # c. Clustering of matches: Based on balls used/ wickets lost/ runs scored by the two teams, can you categorize matches?

# %% [markdown]
# # d. Find the top-5 run-scorers and wicket-takers across all IPL seasons

# %%
ball_by_ball.columns
# Out:
# Index([u'MatcH_id', u'Over_id', u'Ball_id', u'Innings_No', u'Team_Batting',
#        u'Team_Bowling', u'Striker_Batting_Position', u'Extra_Type',
#        u'Runs_Scored', u'Extra_runs', u'Wides', u'Legbyes', u'Byes',
#        u'Noballs', u'Penalty', u'Bowler_Extras', u'Out_type', u'Caught',
#        u'Bowled', u'Run_out', u'LBW', u'Retired_hurt', u'Stumped',
#        u'caught_and_bowled', u'hit_wicket', u'ObstructingFeild',
#        u'Bowler_Wicket', u'Match_Date', u'Season', u'Striker', u'Non_Striker',
#        u'Bowler', u'Player_Out', u'Fielders', u'Striker_match_SK',
#        u'StrikerSK', u'NonStriker_match_SK', u'NONStriker_SK',
#        u'Fielder_match_SK', u'Fielder_SK', u'Bowler_match_SK', u'BOWLER_SK',
#        u'PlayerOut_match_SK', u'BattingTeam_SK', u'BowlingTeam_SK',
#        u'Keeper_Catch', u'Player_out_sk', u'MatchDateSK'],
#       dtype='object')

# %% [markdown]
# <b> Top 5 Players with max score

# %%
player_run_scores = ball_by_ball.groupby('Striker', as_index=False)[['Runs_Scored']].sum()

# %%
player_run_scores.head(5)
# Out:
#    Striker  Runs_Scored
# 0        1         1349
# 1        2         2755
# 2        3           91
# 3        4         1322
# 4        5           64

# %%
player_list.head(5)
# Out:
#    PLAYER_SK  Player_Id      Player_Name         DOB    Batting_hand  \
# 0          0          1       SC Ganguly    7/8/1972   Left-hand bat
# 1          1          2      BB McCullum   9/27/1981  Right-hand bat
# 2          2          3       RT Ponting  12/19/1974  Right-hand bat
# 3          3          4        DJ Hussey   7/15/1977  Right-hand bat
# 4          4          5  Mohammad Hafeez  10/17/1980  Right-hand bat
#
#         Bowling_skill Country_Name
# 0    Right-arm medium        India
# 1    Right-arm medium  New Zealand
# 2    Right-arm medium    Australia
# 3  Right-arm offbreak    Australia
# 4  Right-arm offbreak     Pakistan

# %%
player_runs = pd.merge(player_run_scores, player_list, left_on='Striker', right_on='Player_Id', how='inner').sort_values('Runs_Scored', ascending=False)
player_runs = player_runs[:5]

# %% [markdown]
# * <b> Top 5 Players with max score

# %%
player_runs[['Player_Name', 'Runs_Scored']].head()
# Out:
#     Player_Name  Runs_Scored
# 20     SK Raina         4548
# 7       V Kohli         4413
# 56    RG Sharma         4207
# 39    G Gambhir         4132
# 186   DA Warner         4014

# %% [markdown]
# * <b> Top 5 Bowlers with max wickets

# %%
bowler_wickets_taken = ball_by_ball.groupby('Bowler', as_index=False)[['Bowler_Wicket']].sum()

# %%
bowler_wickets_taken.head(5)
# Out:
#    Bowler  Bowler_Wicket
# 0       1             10
# 1       4              8
# 2       5              2
# 3       8              4
# 4       9             65

# %%
bowler_wickets = pd.merge(bowler_wickets_taken, player_list, left_on='Bowler', right_on='Player_Id', how='inner').sort_values('Bowler_Wicket', ascending=False)
bowler_wickets = bowler_wickets[:5]

# %%
bowler_wickets[['Player_Name', 'Bowler_Wicket']]
# Out:
#          Player_Name  Bowler_Wicket
# 132       SL Malinga            154
# 87          A Mishra            134
# 29   Harbhajan Singh            127
# 41         PP Chawla            126
# 44          DJ Bravo            122

# %% [markdown]
# # e. Histogram of dismisal-types for Virat Kohli

# %%
kohli_data =  pd.merge(ball_by_ball, player_list[player_list.Player_Name == 'V Kohli'], left_on='Striker', right_on='Player_Id', how='inner').sort_values('Runs_Scored', ascending=False)

# %%
kohli_data.head(5)
# Out:
#       MatcH_id  Over_id  Ball_id  Innings_No Team_Batting Team_Bowling  \
# 343     501273       16        6           1            2            3
# 3343    980974       19        6           2            2           12
# 2362    598073        4        6           1            2            3
# 2091    829812        6        5           2            2           11
# 3009    980926       11        5           1            2            6
#
#       Striker_Batting_Position Extra_Type  Runs_Scored  Extra_runs  ...  \
# 343                        3.0  No Extras            6           0  ...
# 3343                       1.0  No Extras            6           0  ...
# 2362                       1.0  No Extras            6           0  ...
# 2091                       2.0  No Extras            6           0  ...
# 3009                       3.0  No Extras            6           0  ...
#
#       Keeper_Catch  Player_out_sk  MatchDateSK  PLAYER_SK  Player_Id  \
# 343              0              0     20110524          7          8
# 3343             0              0     20160507          7          8
# 2362             0              0     20130518          7          8
# 2091             0              0     20150515          7          8
# 3009             0              0     20160417          7          8
#
#       Player_Name        DOB    Batting_hand     Bowling_skill  Country_Name
# 343       V Kohli  11/5/1988  Right-hand bat  Right-arm medium         India
# 3343      V Kohli  11/5/1988  Right-hand bat  Right-arm medium         India
# 2362      V Kohli  11/5/1988  Right-hand bat  Right-arm medium         India
# 2091      V Kohli  11/5/1988  Right-hand bat  Right-arm medium         India
# 3009      V Kohli  11/5/1988  Right-hand bat  Right-arm medium         India
#
# [5 rows x 55 columns]

# %%
kohli_dismissal_data = kohli_data.groupby(['Out_type'])[['Caught','Bowled', 'Run_out', 'LBW', 'Retired_hurt', 'Stumped','caught_and_bowled', 'hit_wicket', 'ObstructingFeild']].sum()
kohli_dismissal_data['dismissal_type'] = kohli_dismissal_data.sum(axis=1)

# %%
kohli_dismissal_data = kohli_dismissal_data.loc[kohli_dismissal_data.index != 'Not Applicable']

# %%
kohli_dismissal_data.head(10)['dismissal_type']
# Out:
# Out_type
# Keeper Catch         14
# bowled               24
# caught               62
# caught and bowled     2
# lbw                   7
# run out              14
# stumped               3
# Name: dismissal_type, dtype: int64

# %%
plt.subplots(figsize=(10,6))
ax=kohli_dismissal_data['dismissal_type'].plot.bar(width=0.9,color=sns.color_palette('RdYlGn',20))
for p in ax.patches:
    ax.annotate(format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))
plt.title('V Kohli dismissal type')
plt.show()

# %% [markdown]
# # Match win predictor

# %% [markdown]
# <b>Prepare Training Data

# %%
scores_df =  pd.merge(ball_by_ball, matches, left_on='MatcH_id', right_on='match_id', how='inner')

scores_df.columns
# Out:
# Index([u'MatcH_id', u'Over_id', u'Ball_id', u'Innings_No', u'Team_Batting',
#        u'Team_Bowling', u'Striker_Batting_Position', u'Extra_Type',
#        u'Runs_Scored', u'Extra_runs', u'Wides', u'Legbyes', u'Byes',
#        u'Noballs', u'Penalty', u'Bowler_Extras', u'Out_type', u'Caught',
#        u'Bowled', u'Run_out', u'LBW', u'Retired_hurt', u'Stumped',
#        u'caught_and_bowled', u'hit_wicket', u'ObstructingFeild',
#        u'Bowler_Wicket', u'Match_Date', u'Season', u'Striker', u'Non_Striker',
#        u'Bowler', u'Player_Out', u'Fielders', u'Striker_match_SK',
#        u'StrikerSK', u'NonStriker_match_SK', u'NONStriker_SK',
#        u'Fielder_match_SK', u'Fielder_SK', u'Bowler_match_SK', u'BOWLER_SK',
#        u'PlayerOut_match_SK', u'BattingTeam_SK', u'BowlingTeam_SK',
#        u'Keeper_Catch', u'Player_out_sk', u'MatchDateSK', u'Match_SK',
#        u'match_id', u'Team1', u'Team2', u'match_date', u'Season_Year',
#        u'Venue_Name', u'City_Name', u'Country_Name', u'Toss_Winner',
#        u'match_winner', u'Toss_Name', u'Win_Type', u'Outcome_Type',
#        u'ManOfMach', u'Win_Margin', u'Country_id'],
#       dtype='object')

# %%
scores_df=  scores_df.loc[scores_df.Outcome_Type.isin(['Result', 'tied'])]

# %%
# wicket on ball
def is_wicket(row):
    if row.Caught == 1 or row.Bowled == 1 or row.Run_out == 1 or row.LBW == 1 or row.Retired_hurt == 1 or row.Stumped == 1 or \
        row.caught_and_bowled == 1 or row.hit_wicket == 1 or row.ObstructingFeild ==1 :
             return 1
    return 0

# %%
# runs on ball
def get_runs(row):
    return row.Runs_Scored + row.Extra_runs + row.Wides + row.Legbyes + row.Byes + row.Noballs + row.Penalty + row.Bowler_Extras

# %%
def is_boundry(row):
    if row.Runs_Scored in [4, 6] or row.Extra_runs in [4, 6] or row.Legbyes in [4, 6] or row.Byes in [4, 6]:
        return 1
    return 0

# %%
scores_df['wicket'] = scores_df.apply(lambda row: is_wicket(row),axis=1)
scores_df['total_runs'] = scores_df.apply(lambda row: get_runs(row),axis=1)
scores_df['boundry'] = scores_df.apply(lambda row: is_boundry(row),axis=1)

# %%
# inning score
innings_df = scores_df.groupby(['MatcH_id', 'Innings_No'], as_index=False)[['total_runs']].sum().reset_index()

# %%
innings_df.sample(5)
# Out:
#       index  MatcH_id  Innings_No  total_runs
# 115     115    336045           2         185
# 524     524    548328           1         142
# 1180   1180   1082613           1         191
# 656     656    598013           1         163
# 426     426    501244           1         185

# %%
# first innings score
first_innings_scores_df = innings_df[innings_df.Innings_No==1]

# %%
first_innings_scores_df.sample(5)
# Out:
#      index  MatcH_id  Innings_No  total_runs
# 204    204    392233           1         171
# 644    644    598006           1         180
# 470    470    501266           1         158
# 120    120    392188           1         116
# 964    964    829776           1         124

# %%
train_df = scores_df.groupby(['MatcH_id', 'Innings_No', 'Over_id', 'Ball_id', 'Team1', 'Team2', 'Team_Batting', 'match_winner'], as_index=False).sum().reset_index()
train_df.columns = train_df.columns.get_level_values(0)

# %%
train_df.columns = train_df.columns.get_level_values(0)

# %%
#current_Score
train_df['current_score'] = train_df.groupby(['MatcH_id', 'Innings_No' ])['total_runs'].cumsum()

# %%
#current_Score
train_df['wicket_down'] = train_df.groupby(['MatcH_id', 'Innings_No' ])['wicket'].cumsum()

# %%
train_df.sample(5)
# Out:
#        index  MatcH_id  Innings_No  Over_id  Ball_id  \
# 98225  98225    733978           1       14        1
# 8641    8641    336023           2        8        6
# 38922  38922    419161           2       19        7
# 19243  19243    392213           2        6        1
# 14978  14978    392194           1       11        6
#
#                              Team1                Team2 Team_Batting  \
# 98225               Mumbai Indians      Kings XI Punjab            4
# 8641                Mumbai Indians  Chennai Super Kings            7
# 38922              Kings XI Punjab      Deccan Chargers            8
# 19243  Royal Challengers Bangalore       Mumbai Indians            2
# 14978          Chennai Super Kings     Delhi Daredevils            6
#
#                       match_winner  Striker_Batting_Position  ...  Match_SK  \
# 98225               Mumbai Indians                       3.0  ...       419
# 8641                Mumbai Indians                       3.0  ...        36
# 38922              Deccan Chargers                       4.0  ...       165
# 19243  Royal Challengers Bangalore                       3.0  ...        83
# 14978             Delhi Daredevils                       2.0  ...        65
#
#        match_id  Season_Year  Win_Margin  Country_id  wicket  total_runs  \
# 98225    733978         2014         5.0           1       0           4
# 8641     336023         2008         9.0           1       0           0
# 38922    419161         2010         5.0           1       0           6
# 19243    392213         2009         9.0           2       0           0
# 14978    392194         2009         9.0           2       0           1
#
#        boundry  current_score  wicket_down
# 98225        1            120            3
# 8641         0            103            1
# 38922        1            194            5
# 19243        0             57            1
# 14978        0             96            3
#
# [5 rows x 58 columns]

# %%
train_df['target_score'] = pd.merge(train_df, first_innings_scores_df, left_on='MatcH_id', right_on='MatcH_id', how='inner')['total_runs_y']

# %%
train_df.sample(10)
# Out:
#          index  MatcH_id  Innings_No  Over_id  Ball_id  \
# 41649    41649    501205           1       17        6
# 30099    30099    419124           2        4        1
# 58249    58249    548312           1        2        1
# 31249    31249    419130           1       12        4
# 103992  103992    734026           1       11        3
# 135591  135591   1082594           2        8        6
# 90206    90206    598065           1        8        2
# 142526  142526   1082624           2       17        6
# 50747    50747    501244           2        9        6
# 146307  146307   1082641           1        2        3
#
#                           Team1                        Team2  \
# 41649      Kochi Tuskers Kerala  Royal Challengers Bangalore
# 30099            Mumbai Indians  Royal Challengers Bangalore
# 58249     Kolkata Knight Riders             Delhi Daredevils
# 31249            Mumbai Indians          Chennai Super Kings
# 103992      Sunrisers Hyderabad  Royal Challengers Bangalore
# 135591          Kings XI Punjab      Rising Pune Supergiants
# 90206            Mumbai Indians          Sunrisers Hyderabad
# 142526  Rising Pune Supergiants  Royal Challengers Bangalore
# 50747           Deccan Chargers        Kolkata Knight Riders
# 146307           Mumbai Indians              Kings XI Punjab
#
#                        Team_Batting                 match_winner  \
# 41649                             9  Royal Challengers Bangalore
# 30099                             2  Royal Challengers Bangalore
# 58249                             1             Delhi Daredevils
# 31249                             3               Mumbai Indians
# 103992                            2          Sunrisers Hyderabad
# 135591              Kings XI Punjab              Kings XI Punjab
# 90206                            11               Mumbai Indians
# 142526  Royal Challengers Bangalore      Rising Pune Supergiants
# 50747                             8        Kolkata Knight Riders
# 146307              Kings XI Punjab              Kings XI Punjab
#
#         Striker_Batting_Position  ...  match_id  Season_Year  Win_Margin  \
# 41649                        5.0  ...    501205         2011         6.0
# 30099                        2.0  ...    419124         2010         7.0
# 58249                        1.0  ...    548312         2012         8.0
# 31249                        4.0  ...    419130         2010         5.0
# 103992                       4.0  ...    734026         2014         7.0
# 135591                       0.0  ...   1082594         2017         6.0
# 90206                        2.0  ...    598065         2013         7.0
# 142526                       0.0  ...   1082624         2017        61.0
# 50747                        2.0  ...    501244         2011        20.0
# 146307                       0.0  ...   1082641         2017         7.0
#
#         Country_id  wicket  total_runs  boundry  current_score  wicket_down  \
# 41649            1       0           2        0            153            3
# 30099            1       0           0        0             18            0
# 58249            1       0           0        0              9            0
# 31249            1       0           1        0            112            2
# 103992           1       0           1        0             55            2
# 135591           1       0           0        0             66            2
# 90206            1       0           4        1             77            1
# 142526           1       0           0        0             88            8
# 50747            1       0           1        0             65            2
# 146307           1       0           1        0             19            0
#
#         target_score
# 41649            180
# 30099            169
# 58249            106
# 31249            204
# 103992           171
# 135591           174
# 90206            191
# 142526           164
# 50747            185
# 146307           249
#
# [10 rows x 59 columns]

# %%
# target remaining
def get_target_remaining(row):
    if row['target_score'] == -1.:
        return -1
    else:
        return row['target_score'] - row['current_score']

# %%
# wicket down
def get_wicket_remaining(row):
    return 10 - row['wicket_down']

# %%
def get_bowls_bowled(row):
    return (row['Over_id']-1)*6 + row['Ball_id']

# %%
def get_bowls_remaining(row):
    balls_bowled = (row['Over_id']-1)*6 + row['Ball_id']
    if balls_bowled <= 120:
        return 120 - balls_bowled
    else:
        return 0

# %%
train_df['target_remaining'] = train_df.apply(lambda row: get_target_remaining(row),axis=1)
train_df['wicket_remaining'] = train_df.apply(lambda row: get_wicket_remaining(row),axis=1)
train_df['balls_bowled'] = train_df.apply(lambda row: get_bowls_bowled(row),axis=1)
train_df['balls_remaining'] = train_df.apply(lambda row: get_bowls_remaining(row),axis=1)

# %%
# team name from id
def get_team_name(row):
    try :
        team_name = teams.loc[teams.Team_Id == int(row.Team_Batting)]

        if team_name.shape[0]>0:
            return team_name.iloc[0]['Team_Name']
        else :
            return row.Team_Batting
    except Exception as ex:
        return row.Team_Batting

# %%
def is_chasing_team_won(row):
    if row.Innings_No == 2 and row.match_winner==row.team_batting_name:
        return 1
    return 0

# %%
train_df['team_batting_name'] = train_df.apply(lambda row: get_team_name(row),axis=1)

# %%
train_df['chasing_team_won'] = train_df.apply(lambda row: is_chasing_team_won(row),axis=1)

# %%
chasing_team_win_predictor_df = train_df.loc[train_df.Innings_No == 2].loc[train_df.balls_remaining<90].copy()

# %%
columns = ['current_score', 'target_score', 'target_remaining', 'wicket_remaining',  'balls_remaining']

norm_columns = ['current_score', 'target_score',  'target_remaining', 'wicket_remaining',
                'balls_remaining']

# %%
def norm_dataset(dataset):
    return dataset

# %%
chasing_team_win_predictor_train_df = chasing_team_win_predictor_df[[col for col in 
                                                                           columns]].copy()
chasing_team_win_predictor_input_dataset = norm_dataset(chasing_team_win_predictor_train_df)
chasing_team_win_predictor_labels = chasing_team_win_predictor_df[['chasing_team_won']]

# %%
train_data, test_data, train_labels, test_labels = cross_validation.train_test_split(chasing_team_win_predictor_input_dataset, 
                                                                                     chasing_team_win_predictor_labels, 
                                                                                     test_size=0.30)


print(train_data.shape)
print(train_labels.shape)

print(test_data.shape)
print(test_labels.shape)
# Out:
# (36446, 5)
# (36446, 1)
# (15620, 5)
# (15620, 1)

# %%
train_data.sample(5)
# Out:
#         current_score  target_score  target_remaining  wicket_remaining  \
# 58348              43           106                63                10
# 21672             121           171                50                 4
# 105308             60           185               125                 9
# 103915            172           173                 1                 5
# 96312             167           191                24                 6
#
#         balls_remaining
# 58348                89
# 21672                27
# 105308               69
# 103915               16
# 96312                 9

# %%
# ada boost
xgb = xgboost.XGBClassifier(max_depth=6, learning_rate=0.1,
                                       n_estimators=1200, silent=True,
                                       objective='binary:logistic',
                                       nthread=-1,
                                       gamma=0, min_child_weight=2,
                                       max_delta_step=0, subsample=0.8,
                                       colsample_bytree=0.8, colsample_bylevel=1,
                                       reg_alpha=0, reg_lambda=1,
                                       scale_pos_weight=1, base_score=0.5,
                                       seed=23, missing=None)
# fitting the model
xgb.fit(train_data, train_labels)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=6, min_child_weight=2, missing=None, n_estimators=1200,
#        n_jobs=1, nthread=-1, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=23, silent=True,
#        subsample=0.8)

# %%
# Model Validation

# predict the response

data_to_test = test_data 
known_test_labels = test_labels 

predicted_test_labels = xgb.predict(data_to_test)


print (accuracy_score(known_test_labels, predicted_test_labels))
print(classification_report(known_test_labels, predicted_test_labels))
print(confusion_matrix(known_test_labels, predicted_test_labels))
# Out:
# 0.9194622279129321
#              precision    recall  f1-score   support
#
#           0       0.92      0.91      0.92      7572
#           1       0.92      0.93      0.92      8048
#
# avg / total       0.92      0.92      0.92     15620
#
# [[6879  693]
#  [ 565 7483]]
# /Library/Python/2.7/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# predict on all data
chasing_team_win_predictor_test_df = chasing_team_win_predictor_df[[col for col in 
                                                                           columns]].copy()
chasing_team_win_predictor_test_dataset = norm_dataset(chasing_team_win_predictor_test_df)
pred_labels = xgb.predict(chasing_team_win_predictor_test_dataset)
pred_probs = xgb.predict_proba(chasing_team_win_predictor_test_dataset)
# Out:
# /Library/Python/2.7/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
# set prediction and winning probability
chasing_team_win_predictor_df['prediction'] = pred_labels
chasing_team_win_predictor_df['winning_probability'] = pred_probs[:, 1]

# %%
# select 10 matches
sample_matches = matches.sample(10)

# %%
output_df = pd.merge(chasing_team_win_predictor_df, sample_matches, left_on='MatcH_id', right_on='match_id', 
                                    how='inner')

# %%
# sample any 10 matches
output_df['MatcH_id'].unique()
# Out:
# array([ 336026,  419144,  419168,  501230,  501258,  548330,  548379,
#         598014,  598053, 1082616])

# %%
# plot winning probability of 10 matches.
fig = plt.figure(figsize=(12,6))
ax = fig.add_subplot(1, 1, 1)
for match_id in output_df['MatcH_id'].unique():
    match_output_df = output_df.loc[output_df.MatcH_id == match_id]
    ax.plot(match_output_df['balls_bowled'], match_output_df['winning_probabilty'])

ax.set_xlabel('Balls Bowled')
ax.set_ylabel('Winning Probabilty')
# Out:
# Text(0,0.5,'Winning Probabilty')

# %%
match_output_df = output_df.loc[output_df.MatcH_id == 501258]

# %%
fig, ax1 = plt.subplots(figsize=(16,6))
ax2 = ax1.twinx()
labels = np.array(match_output_df['balls_bowled'])
ind = np.arange(len(labels))
width = 0.7
rects = ax1.bar(ind, np.array(match_output_df['wicket_remaining']), width=width, color=['red']*45 + ['green']*45)
ax1.set_xticks(ind+((width)/2.))
ax1.set_xticklabels(labels, rotation='vertical')
ax1.set_ylabel("Wikcet Remaining")
ax1.set_xlabel("Ball By Ball Analysis/ Wicket remaining")
ax1.set_title("Win percentage prediction")

ax2.plot(ind+0.35, np.array(match_output_df['winning_probabilty']), color='b', marker='o')
ax2.set_ylabel("Win Probability", color='b')
ax2.set_ylim([0,1])
ax2.grid(b=False)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,6))
ax2 = ax1.twinx()
labels = np.array(match_output_df['balls_bowled'])
ind = np.arange(len(labels))
width = 0.7
rects = ax1.bar(ind, np.array(match_output_df['boundry']), width=width, color=['red']*45 + ['green']*45)
ax1.set_xticks(ind+((width)/2.))
ax1.set_xticklabels(labels, rotation='vertical')
ax1.set_ylabel("Boundry")
ax1.set_xlabel("Ball By Ball Analysis/ boundry")
ax1.set_title("Win percentage prediction")

ax2.plot(ind+0.35, np.array(match_output_df['winning_probabilty']), color='b', marker='o')
ax2.set_ylabel("Win Probability", color='b')
ax2.set_ylim([0,1])
ax2.grid(b=False)
plt.show()
